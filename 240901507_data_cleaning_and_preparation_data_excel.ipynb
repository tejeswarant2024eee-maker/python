# %%
df.columns = df.columns.str.strip() # Clean column names by stripping whitespace
f=df['Student Name'].str.strip()
f.to_excel("dcap.xlsx")

print("\nReplace value:")
k=df.ffill()
print(k)
print("\nUpdated list\n")
k.to_excel("dcap.xlsx")
# Out:
# Replace value:
#    S.No Student Name  Eng  Maths  Phy  Che  Bio  Tamil
# 0     1          Aja   95     96   99   98   96     92
# 1     2        Bison   95     96   58   68   82     25
# 2     3          Cat   63     45   99   98   51     38
# 3     4         Dany    9     85   99   56   89     45
# 4     5        Eliza    6     78   99   58   64     67
# 5     6         Fijo   95     96   99   59   73     92
# 6     7         Gani   94     45   99    2   85     87
# 7     8         Hari   95     96   99    8   96     92
# 8     9        Iniya   58     59   99   98   34     78
# 9    10         Jack   95     96   99   98   96     59
#
# Updated list

# %%
# Updated list
print("\nDrop one particular column and its values:\n")
k.drop(['SOCIAL'],axis=1,inplace=True)
print(k)
print("\nUpdated list..\n")
k.to_excel("dcap.xlsx")
# Out:
# Drop one particular column and its values:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_253/761472007.py in <cell line: 0>()
#       1 # Updated list
#       2 print("\nDrop one particular column and its values:\n")
# ----> 3 k.drop(['SOCIAL'],axis=1,inplace=True)
#       4 print(k)
#       5 print("\nUpdated list..\n")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# ...

# %%
df=pd.read_excel("dcap.xlsx")
print(df)
print("\nExtract using isin() function:\n")
new=df['Eng'].isin([88])
print(df[new])
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  S.No Student Name  ...  Maths  Phy  \
# 0             0             0           0     1          Aja  ...     96   99
# 1             1             1           1     2        Bison  ...     96   58
# 2             2             2           2     3          Cat  ...     45   99
# 3             3             3           3     4         Dany  ...     85   99
# 4             4             4           4     5        Eliza  ...     78   99
# 5             5             5           5     6         Fijo  ...     96   99
# 6             6             6           6     7         Gani  ...     45   99
# 7             7             7           7     8         Hari  ...     96   99
# 8             8             8           8     9        Iniya  ...     59   99
# 9             9             9           9    10         Jack  ...     96   99
#
#    Che  Bio  Tamil
# 0   98   96     92
# 1   68   82     25
# 2   98   51     38
# 3   56   88     45
# ...

# %%
# Updated data list:

print("\nReplace values:\n")
n=pd.read_excel("dcap.xlsx")
print("\nOriginal data:\n")
print(n)
y=n.replace({89:88})
print("\nReplaced dataset:\n")
print(y)
print("\nUpdated dataset:\n")
y.to_excel("dcap.xlsx")
# Out:
# Replace values:
#
#
# Original data:
#
#    Unnamed: 0.1  Unnamed: 0  S.No Student Name  Eng  Maths  Phy  Che  Bio  \
# 0             0           0     1          Aja   95     96   99   98   96
# 1             1           1     2        Bison   95     96   58   68   82
# 2             2           2     3          Cat   63     45   99   98   51
# 3             3           3     4         Dany    9     85   99   56   89
# 4             4           4     5        Eliza    6     78   99   58   64
# 5             5           5     6         Fijo   95     96   99   59   73
# 6             6           6     7         Gani   94     45   99    2   85
# 7             7           7     8         Hari   95     96   99    8   96
# 8             8           8     9        Iniya   58     59   99   98   34
# 9             9           9    10         Jack   95     96   99   98   96
#
#    Tamil
# 0     92
# 1     25
# 2     38
# 3     45
# 4     67
# 5     92
# 6     87
# 7     92
# 8     78
# ...

# %%
# Updated list..
print("\nDrop NaN rows:\n")
df=pd.read_excel("dcap.xlsx")
print(df)
x=df.dropna()
print(x)
print("\nUpdated data list:\n")
x.to_excel("dcap.xlsx")
# Out:
# Drop NaN rows:
#
#    Unnamed: 0  S.No Student Name  Eng  Maths  Phy  Che  Bio  Tamil
# 0           0     1          Aja   95     96   99   98   96     92
# 1           1     2        Bison   95     96   58   68   82     25
# 2           2     3          Cat   63     45   99   98   51     38
# 3           3     4         Dany    9     85   99   56   89     45
# 4           4     5        Eliza    6     78   99   58   64     67
# 5           5     6         Fijo   95     96   99   59   73     92
# 6           6     7         Gani   94     45   99    2   85     87
# 7           7     8         Hari   95     96   99    8   96     92
# 8           8     9        Iniya   58     59   99   98   34     78
# 9           9    10         Jack   95     96   99   98   96     59
#    Unnamed: 0  S.No Student Name  Eng  Maths  Phy  Che  Bio  Tamil
# 0           0     1          Aja   95     96   99   98   96     92
# 1           1     2        Bison   95     96   58   68   82     25
# ...

# %%
print("Columns in DataFrame k:")
print(k.columns)
# Out:
# Columns in DataFrame k:
# Index(['S.No', 'Student Name', 'Eng', 'Maths', 'Phy', 'Che', 'Bio', 'Tamil'], dtype='object')

# %%
df.columns = df.columns.str.strip() # Ensure column names are clean
f=df['Student Name'].str.strip()
f.to_excel("dcap.xlsx")

print("\nReplace value:")
k=df.ffill()
print(k)
print("\nUpdated list\n")
k.to_excel("dcap.xlsx")
# Out:
# Replace value:
#    S.No Student Name  Eng  Maths  Phy  Che  Bio  Tamil
# 0     1          Aja   95     96   99   98   96     92
# 1     2        Bison   95     96   58   68   82     25
# 2     3          Cat   63     45   99   98   51     38
# 3     4         Dany    9     85   99   56   89     45
# 4     5        Eliza    6     78   99   58   64     67
# 5     6         Fijo   95     96   99   59   73     92
# 6     7         Gani   94     45   99    2   85     87
# 7     8         Hari   95     96   99    8   96     92
# 8     9        Iniya   58     59   99   98   34     78
# 9    10         Jack   95     96   99   98   96     59
#
# Updated list

# %%
import pandas as pd
pd.set_option('display.max_columns',10)
print("Original data:\n")
df=pd.read_excel("/content/II EEE marks (1).xlsx")
print(df)
# Out:
# Original data:
#
#    S.No Student Name   Eng  Maths  Phy  Che  Bio  Tamil
# 0     1           Aja   95     96   99   98   96     92
# 1     2         Bison   95     96   58   68   82     25
# 2     3           Cat   63     45   99   98   51     38
# 3     4          Dany    9     85   99   56   89     45
# 4     5         Eliza    6     78   99   58   64     67
# 5     6          Fijo   95     96   99   59   73     92
# 6     7          Gani   94     45   99    2   85     87
# 7     8          Hari   95     96   99    8   96     92
# 8     9         Iniya   58     59   99   98   34     78
# 9    10          Jack   95     96   99   98   96     59
