# %%
print(sns.scatterplot(data=ypoints))
print(plt.show())
# Out:
# Axes(0.125,0.11;0.775x0.77)
# None

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly.express as px

#seaborn package
Xpoints=np.array([0,20,120,200])
Ypoints=np.array([10,80,100,120,150,180,250])

# %%
print(sns.barplot(data=ypoints))
print(plt.show())
# Out:
# Axes(0.125,0.11;0.775x0.77)
# None

# %%
#3-D plot
X_3d=np.array([1,2,6,8,12,14,20])
Y_3d=np.array([3,8,1,10,12,16,18])
Fig=plt.figure(figsize=(12,8))
Ax=plt.axes(projection='3d') # Fixed typo 'prohection' and invalid character
Plt_3d=Ax.scatter3D(X_3d,Y_3d) # Fixed 'ax' to 'Ax' and 'x','y' to 'X_3d','Y_3d'
# plt.colorbar(Plt_3d) # Removed/commented out as it often requires 'c' argument in scatter3D
plt.show() # Fixed 'Plt' to 'plt'

#plotly package
X_plotly=np.array([10,80,100,120,150,180,250])

fig=px.scatter(x=X_plotly) # Passed array 'X_plotly' using the 'x' keyword argument
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
